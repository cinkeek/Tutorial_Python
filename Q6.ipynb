# %% [markdown]
# ## Square Root

# %%
n = float(input("Enter number: "))
x = n
for _ in range(20):
    x = 0.5 * (x + n / x)
print("Square root =", x)
# Out:
# Enter number:  625
# Square root = 25.0
